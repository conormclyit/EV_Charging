# %% [markdown]
# <a href="https://colab.research.google.com/github/conormclyit/EV_Charging/blob/main/Final%20Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Libraries

# %%
pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-1.1.2-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 3.8 MB/s
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.3.5)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.21.6)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.6 MB/s
# Requirement already satisfied: Shapely<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.8.1.post1)
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.6.3)
# Collecting geopandas>=0.10
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 57.1 MB/s
# Collecting pyproj>=3.2
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 53.2 MB/s
# Collecting Rtree>=0.9
#   Downloading Rtree-1.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 29.3 MB/s
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 31.4 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 50.1 MB/s
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (21.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (57.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (7.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (2021.10.8)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 34.1 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (3.0.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.4->osmnx) (4.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3->osmnx) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (1.24.3)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fonttools, fiona, Rtree, requests, matplotlib, geopandas, osmnx
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Rtree-1.0.0 click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 fonttools-4.33.3 geopandas-0.10.2 matplotlib-3.5.1 munch-2.5.0 osmnx-1.1.2 pyproj-3.2.1 requests-2.27.1

# %% [markdown]
# Load Libraries

# %%
## for data
import numpy as np
import pandas as pd
## for plotting
import matplotlib.pyplot as plt
## for geospatial
import folium
import geopy
## for machine learning
from sklearn import preprocessing, cluster
import scipy

# %% [markdown]
# Graph of Dublin Road Network

# %%
import osmnx as ox
import networkx as nx

# %%
G = ox.graph_from_place('Dublin', custom_filter='["highway"~"motorway|trunk|primary|secondary|tertiary"]')
fig, ax = ox.plot_graph(G)

# %%
# to geodataframe, access edge info.
edges = ox.graph_to_gdfs(G, nodes=False, edges=True)

# %%
len(G.edges)
# Out:
# 2515

# %% [markdown]
# Load Dublin EV Charging Stations

# %%
# import dublin charging stations
from google.colab import files
dublin_ev = files.upload()
# Out:
#      <input type="file" id="files-503d6a5c-0ccb-44f3-a121-fca3c15baaf4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-503d6a5c-0ccb-44f3-a121-fca3c15baaf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Dublin_Charging_Stations.csv to Dublin_Charging_Stations.csv

# %%
import pandas as pd
import io
 
dublin_ev = pd.read_csv(io.BytesIO(dublin_ev['Dublin_Charging_Stations.csv']),encoding='latin-1')
dublin_ev.head()
# Out:
#    ï»¿id                                               name  \
# 0     26  Castleknock Hotel and Country Club, Porterstow...
# 1     27  Bewleys Hotel Leopardstown, Central Park, Leop...
# 2     28  Westbury Hotel, Grafton Street, Dublin 2, Coun...
# 3     29  Merrion Hotel, Upper Merrion Street, Dublin 2,...
# 4     30  The Westin Dublin, Westmoreland Street, Dublin...
#
#                                          description         styleUrl  \
# 0  <IconStyle><Icon><img src="https://www.esb.ie/...  #Other_Services
# 1  <IconStyle><Icon><img src="https://www.esb.ie/...  #Other_Services
# 2  <IconStyle><Icon><img src="https://www.esb.ie/...  #Other_Services
# 3  <IconStyle><Icon><img src="https://www.esb.ie/...  #Other_Services
# 4  <IconStyle><Icon><img src="https://www.esb.ie/...  #Other_Services
#
#    longitude   latitude          town  county
# 0  -6.392840  53.366930   Castleknock  Dublin
# 1  -6.206086  53.271314  Leopardstown  Dublin
# 2  -6.261259  53.341351      Dublin 2  Dublin
# 3  -6.252900  53.338500      Dublin 2  Dublin
# 4  -6.258945  53.345479      Dublin 2  Dublin

# %%
dublin_ev = dublin_ev.drop(columns=['description','styleUrl'])

# %%
city = "Dublin"
## get location
locator = geopy.geocoders.Nominatim(user_agent="MyCoder")
location = locator.geocode(city)
print(location)
## keep latitude and longitude only
location = [location.latitude, location.longitude]
print("[lat, long]:", location)
# Out:
# Dublin, Dublin 1, Leinster, Éire / Ireland
# [lat, long]: [53.3497645, -6.2602732]

# %% [markdown]
# Import Dublin Neighbhourhoods

# %%
# import dublin areas
from google.colab import files
dublin_areas = files.upload()
# Out:
#      <input type="file" id="files-8cf3d2c4-aaf8-4eb9-8078-ef8e9c9e790e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8cf3d2c4-aaf8-4eb9-8078-ef8e9c9e790e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Dublin_Neighbourhoods.csv to Dublin_Neighbourhoods.csv

# %%
import pandas as pd
import io
 
dublin_areas = pd.read_csv(io.BytesIO(dublin_areas['Dublin_Neighbourhoods.csv']),encoding='latin-1')
dublin_areas.head()
# Out:
#   ï»¿Dublin Side Neighbourhood  Population
# 0      Northside        Artane       36564
# 1      Northside       Ashtown       22740
# 2      Northside    Balbriggan       21722
# 3      Northside    Ballybough        3718
# 4      Northside  Ballyboughal        1946

# %% [markdown]
# Add Lat and Lon to Dublin Neighbourhoods using Nominatim

# %%
from geopy.geocoders import Nominatim

# %%
latitudeList = []
longitudeList = []

for neigh in dublin_areas.Neighbourhood:
    try:
        address = f'{neigh}, Dublin'
        geolocator = Nominatim(user_agent='dublin_explorer')
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        latitudeList.append(latitude)
        longitudeList.append(longitude)     
    except:
        latitudeList.append(None)
        longitudeList.append(None)

# %%
dublin_areas['Latitude'] = latitudeList
dublin_areas['Longitude'] = longitudeList

# %%
print(dublin_areas['Latitude'].isna().sum())
dublin_areas.drop(dublin_areas[dublin_areas['Latitude'].isnull()].index, axis=0, inplace=True)
print(dublin_areas['Latitude'].isna().sum())
dublin_areas.reset_index(inplace=True)
del dublin_areas['index']
dublin_areas.head(2)
# Out:
# 0
# 0
#   ï»¿Dublin Side Neighbourhood  Population   Latitude  Longitude
# 0      Northside        Artane       36564  53.382500  -6.202500
# 1      Northside       Ashtown       22740  53.375406  -6.331814

# %% [markdown]
# Map Dublin Neighbourhoods

# %%
DublinMap = folium.Map(location=[53.347598, -6.259343], zoom_start=11)

for lat, long, label, pop in zip(dublin_areas.Latitude, dublin_areas.Longitude, dublin_areas.Neighbourhood, dublin_areas.Population):
    folium.CircleMarker([lat, long], radius=pop*0.001, popup=label, color='green', fill=True, fill_opacity=0.2).add_to(DublinMap)

DublinMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_470e0be8305786405bef35286974633f {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_470e0be8305786405bef35286974633f&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_470e0be8305786405bef35286974633f = L.map(
#         &#x27;map_470e0be8305786405bef35286974633f&#x27;, {
#         center: [53.347598, -6.259343],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_66931fc3f89dd3b52fdcfab0eee1007f = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_470e0be8305786405bef35286974633f);
#
#             var circle_marker_76ec85d2cb9dd92b0f3a002df1b19355 = L.circleMarker(
#                 [53.3825, -6.2025],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 36.564,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_470e0be8305786405bef35286974633f);
#
#
#             var popup_f03dd95279058c16e206b2f3f380697a = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_3820bae1ddb02b69e889040b77374c1b = $(`&lt;div id=&quot;html_3820bae1ddb02b69e889040b77374c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artane&lt;/div&gt;`)[0];
#                 popup_f03dd95279058c16e206b2f3f380697a.setContent(html_3820bae1ddb02b69e889040b77374c1b);
#
#
#             circle_marker_76ec85d2cb9dd92b0f3a002df1b19355.bindPopup(popup_f03dd95279058c16e206b2f3f380697a)
#             ;
#
#
#
#
#             var circle_marker_ecb1bd1b0e984e1aa59ca6e50ab239ca = L.circleMarker(
#                 [53.3754061, -6.3318144],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 22.740000000000002,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_470e0be8305786405bef35286974633f);
#
#
#             var popup_23cd5318a636b65e6f5a128db131595d = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_ec7d839a5f65305137654dc08664f93a = $(`&lt;div id=&quot;html_ec7d839a5f65305137654dc08664f93a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ashtown&lt;/div&gt;`)[0];
#                 popup_23cd5318a636b65e6f5a128db131595d.setContent(html_ec7d839a5f65305137654dc08664f93a);
#
#
#             circle_marker_ecb1bd1b0e984e1aa59ca6e50ab239ca.bindPopup(popup_23cd5318a636b65e6f5a128db131595d)
#             ;
#
#
#
#
#             var circle_marker_705a8328e50d977ccfd3b527ef96a5af = L.circleMarker(
#                 [53.609832, -6.1861964],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 21.722,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_470e0be8305786405bef35286974633f);
#
#
#             var popup_e725127bfc47106f011498c39f182ea9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_363a05b65a4856c94e8a4c92435668c5 = $(`&lt;div id=&quot;html_363a05b65a4856c94e8a4c92435668c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Balbriggan&lt;/div&gt;`)[0];
#                 popup_e725127bfc47106f011498c39f182ea9.setContent(html_363a05b65a4856c94e8a4c92435668c5);
#
#
#             circle_marker_705a8328e50d977ccfd3b527ef96a5af.bindPopup(popup_e725127bfc47106f011498c39f182ea9)
#             ;
#
#
#
#
#             var circle_marker_f78ef088100500b2d558bec4502988b8 = L.circleMarker(
#                 [53.3613503, -6.2461912],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 3.718,
#   &quot;stroke&quot;: true,
#   &quo

# %% [markdown]
# Map Dublin EV Stations

# %%
DublinEVMap = folium.Map(location=[53.347598, -6.259343], zoom_start=11)

for lat, long, label in zip(dublin_ev.latitude, dublin_ev.longitude, dublin_ev.name):
    folium.CircleMarker([lat, long], radius=10, popup=label, color='red', fill=True, fill_opacity=0.2).add_to(DublinEVMap)

DublinEVMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_d2c028b10b4fde4be632459fa3941aff {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_d2c028b10b4fde4be632459fa3941aff&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_d2c028b10b4fde4be632459fa3941aff = L.map(
#         &#x27;map_d2c028b10b4fde4be632459fa3941aff&#x27;, {
#         center: [53.347598, -6.259343],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_f76cb30f07a4c664ca464576bb8fdf93 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#             var circle_marker_8b0228e227caf0d57ef5bd37011f52f8 = L.circleMarker(
#                 [53.36693, -6.39284],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#
#             var popup_0a77fd1a2e99ef7c8eb94a6cf483878f = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_205fe05c73d7f7476fb71cc2835c5b2f = $(`&lt;div id=&quot;html_205fe05c73d7f7476fb71cc2835c5b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castleknock Hotel and Country Club, Porterstown Road, Castleknock, Dublin 15, County Dublin&lt;/div&gt;`)[0];
#                 popup_0a77fd1a2e99ef7c8eb94a6cf483878f.setContent(html_205fe05c73d7f7476fb71cc2835c5b2f);
#
#
#             circle_marker_8b0228e227caf0d57ef5bd37011f52f8.bindPopup(popup_0a77fd1a2e99ef7c8eb94a6cf483878f)
#             ;
#
#
#
#
#             var circle_marker_1f51a1a8d81198eb10e2a57d2eea17fc = L.circleMarker(
#                 [53.271314, -6.206086],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#
#             var popup_a60527579ebea0903b294de2524dbc79 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_e427a8b4e577be490292a117cb97f4e9 = $(`&lt;div id=&quot;html_e427a8b4e577be490292a117cb97f4e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bewleys Hotel Leopardstown, Central Park, Leopardstown, Dublin 18, County Dublin&lt;/div&gt;`)[0];
#                 popup_a60527579ebea0903b294de2524dbc79.setContent(html_e427a8b4e577be490292a117cb97f4e9);
#
#
#             circle_marker_1f51a1a8d81198eb10e2a57d2eea17fc.bindPopup(popup_a60527579ebea0903b294de2524dbc79)
#             ;
#
#
#
#
#             var circle_marker_14de1544531666bd2acc7ba31399ddf3 = L.circleMarker(
#                 [53.341351, -6.261259],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#
#             var popup_e8b8ae8a1187334afa9d1f9eb5e0cfc3 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_801b95b550b476491cb9b98b884eb96e = $(`&lt;div id=&quot;html_801b95b550b476491cb9b98b884eb96e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Westbury Hotel, Grafton Street, Dublin 2, County Dublin&lt;/div&gt;`)[0];
#                 popup_e8b8ae8a1187334afa9d1f9eb5e0cfc3.setContent(html_801b95b550b476491cb9b98b884eb96e);
#
#
#             circle_marker_14de1544531666bd2acc7ba31399ddf3.bindPopup(popup_e8b8ae8a1187334afa9d1f9eb5e0cfc3)
#             ;
#
#
#
#
#             var circle_marker_7558af9c6728889cc63d48d2152459df = L.circleMarker(
#                 [53.3385, -6.2529],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot

# %% [markdown]
# Map Dublin EV Charging Stations alongside Dublin Neighbourhoods

# %%
for lat, long, label in zip(dublin_ev.latitude, dublin_ev.longitude, dublin_ev.name):
    folium.CircleMarker([lat, long], radius=10, popup=label, color='red', fill=True, fill_opacity=0.2).add_to(DublinMap)

DublinMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_470e0be8305786405bef35286974633f {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_470e0be8305786405bef35286974633f&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_470e0be8305786405bef35286974633f = L.map(
#         &#x27;map_470e0be8305786405bef35286974633f&#x27;, {
#         center: [53.347598, -6.259343],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_66931fc3f89dd3b52fdcfab0eee1007f = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_470e0be8305786405bef35286974633f);
#
#             var circle_marker_76ec85d2cb9dd92b0f3a002df1b19355 = L.circleMarker(
#                 [53.3825, -6.2025],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 36.564,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_470e0be8305786405bef35286974633f);
#
#
#             var popup_f03dd95279058c16e206b2f3f380697a = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_3820bae1ddb02b69e889040b77374c1b = $(`&lt;div id=&quot;html_3820bae1ddb02b69e889040b77374c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artane&lt;/div&gt;`)[0];
#                 popup_f03dd95279058c16e206b2f3f380697a.setContent(html_3820bae1ddb02b69e889040b77374c1b);
#
#
#             circle_marker_76ec85d2cb9dd92b0f3a002df1b19355.bindPopup(popup_f03dd95279058c16e206b2f3f380697a)
#             ;
#
#
#
#
#             var circle_marker_ecb1bd1b0e984e1aa59ca6e50ab239ca = L.circleMarker(
#                 [53.3754061, -6.3318144],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 22.740000000000002,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_470e0be8305786405bef35286974633f);
#
#
#             var popup_23cd5318a636b65e6f5a128db131595d = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_ec7d839a5f65305137654dc08664f93a = $(`&lt;div id=&quot;html_ec7d839a5f65305137654dc08664f93a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ashtown&lt;/div&gt;`)[0];
#                 popup_23cd5318a636b65e6f5a128db131595d.setContent(html_ec7d839a5f65305137654dc08664f93a);
#
#
#             circle_marker_ecb1bd1b0e984e1aa59ca6e50ab239ca.bindPopup(popup_23cd5318a636b65e6f5a128db131595d)
#             ;
#
#
#
#
#             var circle_marker_705a8328e50d977ccfd3b527ef96a5af = L.circleMarker(
#                 [53.609832, -6.1861964],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 21.722,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_470e0be8305786405bef35286974633f);
#
#
#             var popup_e725127bfc47106f011498c39f182ea9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_363a05b65a4856c94e8a4c92435668c5 = $(`&lt;div id=&quot;html_363a05b65a4856c94e8a4c92435668c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Balbriggan&lt;/div&gt;`)[0];
#                 popup_e725127bfc47106f011498c39f182ea9.setContent(html_363a05b65a4856c94e8a4c92435668c5);
#
#
#             circle_marker_705a8328e50d977ccfd3b527ef96a5af.bindPopup(popup_e725127bfc47106f011498c39f182ea9)
#             ;
#
#
#
#
#             var circle_marker_f78ef088100500b2d558bec4502988b8 = L.circleMarker(
#                 [53.3613503, -6.2461912],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 3.718,
#   &quot;stroke&quot;: true,
#   &quo

# %%
dublin_areas.head()
# Out:
#   ï»¿Dublin Side Neighbourhood  Population   Latitude  Longitude
# 0      Northside        Artane       36564  53.382500  -6.202500
# 1      Northside       Ashtown       22740  53.375406  -6.331814
# 2      Northside    Balbriggan       21722  53.609832  -6.186196
# 3      Northside    Ballybough        3718  53.361350  -6.246191
# 4      Northside  Ballyboughal        1946  53.520524  -6.267497

# %% [markdown]
# K-Means Cluster

# %%
from sklearn.cluster import KMeans

# %%
dublin_ev
# Out:
#      ï»¿id                                               name  longitude  \
# 0       26  Castleknock Hotel and Country Club, Porterstow...  -6.392840
# 1       27  Bewleys Hotel Leopardstown, Central Park, Leop...  -6.206086
# 2       28  Westbury Hotel, Grafton Street, Dublin 2, Coun...  -6.261259
# 3       29  Merrion Hotel, Upper Merrion Street, Dublin 2,...  -6.252900
# 4       30  The Westin Dublin, Westmoreland Street, Dublin...  -6.258945
# ..     ...                                                ...        ...
# 126    558  Talbot Hotel Stillorgan, Stillorgan Road, Stil...  -6.203373
# 127    605  Hutton and Meade (Nissan), Unit 600 North West...  -6.357533
# 128    606  Windsor Motors Belgard (Nissan), Belgard Road,...  -6.369400
# 129    607  Windsor Motors Deansgrange (Nissan), Deansgran...  -6.165920
# 130    608  Nissan, Windsor Motors Airside, Airside Motor ...  -6.222570
#
#       latitude            town  county
# 0    53.366930     Castleknock  Dublin
# 1    53.271314    Leopardstown  Dublin
# 2    53.341351        Dublin 2  Dublin
# 3    53.338500        Dublin 2  Dublin
# 4    53.345479        Dublin 2  Dublin
# ..         ...             ...     ...
# 126  53.295343      Stillorgan  Dublin
# 127  53.416286  Blanchardstown  Dublin
# 128  53.295000       Dublin 24  Dublin
# 129  53.283300       Dublin 24  Dublin
# 130  53.445900          Swords  Dublin
#
# [131 rows x 6 columns]

# %%
# Variable with the Longitude and Latitude
X=dublin_ev.loc[:,['town','latitude','longitude']]

# %%
K_clusters = range(1,10)

kmeans = [KMeans(n_clusters=i) for i in K_clusters]

Y_axis = dublin_ev[['longitude']]
X_axis = dublin_ev[['latitude']]

score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]

# %%
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')

plt.ylabel('Score')

plt.title('Elbow Curve')

plt.show()

# %%
# Create Clusters and Visualise
kmeans = KMeans(n_clusters = 4, init ='k-means++')
kmeans.fit(X[X.columns[1:3]]) # Compute k-means clustering.

X['cluster_label'] = kmeans.fit_predict(X[X.columns[1:3]])

centers = kmeans.cluster_centers_ # Coordinates of cluster centers.

labels = kmeans.predict(X[X.columns[1:3]]) # Labels of each point

#Visualise Resutls
X.plot.scatter(x = 'latitude', y = 'longitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.title('Clustering GPS Co-ordinates to Form Regions',fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Clustering GPS Co-ordinates to Form Regions')

# %% [markdown]
# Install Python Google Places to get POI

# %%
# !pip install python-google-places
# Out:
# Collecting python-google-places
#   Downloading python-google-places-1.4.2.tar.gz (12 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from python-google-places) (1.15.0)
# Building wheels for collected packages: python-google-places
#   Building wheel for python-google-places (setup.py) ... done
#   Created wheel for python-google-places: filename=python_google_places-1.4.2-py3-none-any.whl size=13606 sha256=3d3ae0e33c79c1f1bae35656e7760edbde5b88833459413d6db282eba9467006
#   Stored in directory: /root/.cache/pip/wheels/e6/1b/c7/bcaf3c3822813b8b3d621e1b853a25db9788d9eb00e702af4e
# Successfully built python-google-places
# Installing collected packages: python-google-places
# Successfully installed python-google-places-1.4.2

# %%
from googleplaces import GooglePlaces

YOUR_API_KEY = 'AIzaSyAlppV6AKToMFxhRlYsgbSxCFgG8sO_Bpk'

google_places = GooglePlaces(YOUR_API_KEY)

query_result = google_places.nearby_search(
  lat_lng = {'lat': 53.3786, 'lng': -6.0570}, 
  keyword='Restaurant',
  radius=10000
)

for place in query_result.places:
  print(place.name)
# Out:
# Bay Restaurant
# Bianconi's Ristorante and Pizzeria
# 8a Brasserie
# La Gustosa
# Suas Restaurant
# MAX'S
# Fish Shack Sandycove
# Casper & Giumbini's
# Purple Sage Restaurant
# Ravello Restaurant
# Romayo's Diner Clongriffin
# Bon Appetit
# Coal
# Lobstar
# Mulino Italian Restaurant
# Taza
# The Sandbar
# The Baths at Clontarf
# Old Street Restaurant
# Picasso Restaurant Clontarf

# %%
import requests
import json
import time
resturant_poi = []
params = {}
  
endpoint_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurant&location=53.3786,-6.0570&radius=10000&key=AIzaSyAlppV6AKToMFxhRlYsgbSxCFgG8sO_Bpk"
         
res = requests.get(endpoint_url, params = params)
results =  json.loads(res.content)
resturant_poi.extend(results['results'])
time.sleep(2)
while "next_page_token" in results:
     params['pagetoken'] = results['next_page_token'],
     res = requests.get(endpoint_url, params = params)
     results = json.loads(res.content)
     resturant_poi.extend(results['results'])
     time.sleep(2)

# %%
poi_name = []
poi_address = []
poi_lat = []
poi_lon = []
poi_type = []

for i in range(len(resturant_poi)):

  restaurant = resturant_poi[i]

  try:
    poi_name.append(restaurant['name'])
  except:
    poi_name.append('none')

  try:
    poi_address.append(restaurant['formatted_address'])
  except:
    poi_address.append('none')

  try:
    poi_lat.append(restaurant['geometry']['location']['lat'])
  except:
    poi_lat.append('none')

  try:
    poi_lon.append(restaurant['geometry']['location']['lng'])
  except:
    poi_lon.append('none')  

  try:
    poi_type.append(restaurant['types'])
  except:
    poi_type.append('none')

# %%
resturant_poi
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '369 Clontarf Rd, Clontarf, Dublin 3, Ireland',
#   'geometry': {'location': {'lat': 53.3630703, 'lng': -6.1785899},
#    'viewport': {'northeast': {'lat': 53.36437597989272,
#      'lng': -6.177119020107279},
#     'southwest': {'lat': 53.36167632010728, 'lng': -6.179818679892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Bay Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1360,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108741161077182092916">Bay Restaurant</a>'],
#     'photo_reference': 'Aap_uEC2-ydMMIS3XoU_pKNFa4gyrQTIwV2yil2Pvxu__s_VKEUVaQnjuzI_Y4JgIwCoTcrsmma73s2aNhBCFKVL5tLzXfAoC2J07V10R_5tnTXtlS75IJTIPy0dhoDXiUFpmHXSK5fTn5eISRbyrDQSCCVhVT0FNHgoIVkokelfzFUMT_oA',
#     'width': 2048}],
#   'place_id': 'ChIJr2Px3AkPZ0gRf_SKx8QeggI',
#   'plus_code': {'compound_code': '9R7C+6H Dublin 3, Ireland',
#    'global_code': '9C5M9R7C+6H'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJr2Px3AkPZ0gRf_SKx8QeggI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1129},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '232 Merrion Rd, Dublin 4, D04 RH61, Ireland',
#   'geometry': {'location': {'lat': 53.317495, 'lng': -6.2081551},
#    'viewport': {'northeast': {'lat': 53.31881542989272,
#      'lng': -6.206798070107276},
#     'southwest': {'lat': 53.31611577010727, 'lng': -6.20949772989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Bianconi's Ristorante and Pizzeria",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4640,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114438714597049766460">Kane Undabel</a>'],
#     'photo_reference': 'Aap_uECpMlMMIKnZSk35EGXYDeXCHSh1bYc80fHHVtnSB9AFRVmvqtGnRiM-E1GSwPrMq8JNXI4huzVzzSWHKcoFp2HLeFFU03ERFhLqsItD2INzCgnW3ZZl4t0eUpR7gDQqx4XZzLA5KYIIiTkwwrU9aGiDuceGDLLydmiYw0Y4NOsvEoBw',
#     'width': 2610}],
#   'place_id': 'ChIJYVoZGtUOZ0gRDQndt75OJRI',
#   'plus_code': {'compound_code': '8Q9R+2P Dublin 4, Ireland',
#    'global_code': '9C5M8Q9R+2P'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJYVoZGtUOZ0gRDQndt75OJRI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 313},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '8A Monkstown Cres, Monkstown, Co. Dublin, A94 N6D3, Ireland',
#   'geometry': {'location': {'lat': 53.2939829, 'lng': -6.152665499999999},
#    'viewport': {'northeast': {'lat': 53.29527372989272,
#      'lng': -6.151327170107278},
#     'southwest': {'lat': 53.29257407010727, 'lng': -6.154026829892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '8a Brasserie',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103545590678612496378">8a Brasserie</a>'],
#     'photo_reference': 'Aap_uEC_YRqli9V3jts43EUur7fkyoGACpAwsE27WqvZ-rWilnHLiiVb_Jlg_6BjAKR8THL8KRjYxiSEnn--fexnv5eLxbBA6rMd4iHASNSvTKbwcLlbPEMElPNW4K9GKrK63YTtsFb-TV53OLigTCtTktJQoApRqC9pxi4dYg4LH_QLfxxi',
#     'width': 4896}],
#   'place_id': 'ChIJd-XUJpkIZ0gRAKPm_gv2g2s',
#   'plus_code': {'compound_code': '7RVW+HW Monkstown, County Dublin, Ireland',
#    'global_code': '9C5M7RVW+HW'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJd-XUJpkIZ0gRAKPm_gv2g2s',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 378},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '12a Dublin Rd, Bayside, Dublin 13, D13 RW26, Ireland',
#   'geometry': {'location': {'lat': 53.3855709, 'lng': -6.1405921},
#    'viewport': {'northeast': {'lat': 53.38688147989272,
#      'lng': -6.139214670107278},
#     'southwest': {'lat': 53.38418182010728, 'lng': -6.141914329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'La Gustosa',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115786569213065615890">Mark G Kiernan</a>'],
#     'photo_reference': 'Aap_uEC9LhCxcj7kV2faUmfe65rNovezU6jZQfefvrPs9onJPLlcSNMcRVvLay3N5WMa7798gRYlCXfxNkMhS1dr0qNWxkcPQ8vynzcq8AcvAtd9DJlQffUDcQPxB4VdZNvaJwHO3iDUcrLbgwAvNrjPLOlUtSdkr3giTT31FO1KcIUcg2nE',
#     'width': 4032}],
#   'place_id': 'ChIJ8fiHpeAFZ0gR_hsyaM7thmQ',
#   'plus_code': {'compound_code': '9VP5+6Q Dublin 13, Ireland',
#    'global_code': '9C5M9VP5+6Q'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJ8fiHpeAFZ0gR_hsyaM7thmQ',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 316},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '411 Howth Rd, Clontarf East, Dublin 5, D05 Y1E5, Ireland',
#   'geometry': {'location': {'lat': 53.379835, 'lng': -6.1772057},
#    'viewport': {'northeast': {'lat': 53.38124832989272,
#      'lng': -6.175835270107279},
#     'southwest': {'lat': 53.37854867010728, 'lng': -6.178534929892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Suas Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118177490338299951487">Chris Judge</a>'],
#     'photo_reference': 'Aap_uEBCyx786bHbxQUV-aar0dfi86nPkxyq307nRP1XWyeKdU2xiXpAFmG-2DBEAviX-PNPv4mgEtvFTOPTnbFHm8Mrlt2JndTAxTNDSwqIgTZUMqhyY28_dJPaTvSY7APsewls0CXXsR3ataDjPfueTnewwU-DRZnwI4XHeiE8u-esGp-J',
#     'width': 4032}],
#   'place_id': 'ChIJY75AeY0PZ0gRjW08_eghqFM',
#   'plus_code': {'compound_code': '9RHF+W4 Dublin 5, Ireland',
#    'global_code': '9C5M9RHF+W4'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJY75AeY0PZ0gRjW08_eghqFM',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 444},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '9 Vernon Ave, Clontarf, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.3596099, 'lng': -6.1958164},
#    'viewport': {'northeast': {'lat': 53.36096627989271,
#      'lng': -6.194558670107278},
#     'southwest': {'lat': 53.35826662010727, 'lng': -6.197258329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "MAX'S",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3732,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103816476116375201502">A Google User</a>'],
#     'photo_reference': 'Aap_uEAc7JItVAN7BChssYQyY4RGZsw1F7kkCc8A5U_htIyW2l3odBDyELXVTrgRxdb20NtCX4Po2q1g-VKV1Ew2zpzmvinC2BN_Wq3APVYMTKRIVNGc1uQNF6Kb6Fyh8s8sJuMPxg_xTttQLOc4m9EZ6AShD3cWZNG_dNLuDnxQOFsdtlR2',
#     'width': 5598}],
#   'place_id': 'ChIJM72tbGIPZ0gRohuG6gxMTjo',
#   'plus_code': {'compound_code': '9R53+RM Dublin, Ireland',
#    'global_code': '9C5M9R53+RM'},
#   'rating': 4.2,
#   'reference': 'ChIJM72tbGIPZ0gRohuG6gxMTjo',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 130},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1 Martello Terrace, Sandycove, Dublin, A96 XY75, Ireland',
#   'geometry': {'location': {'lat': 53.2891853, 'lng': -6.1255077},
#    'viewport': {'northeast': {'lat': 53.29060217989272,
#      'lng': -6.124026770107277},
#     'southwest': {'lat': 53.28790252010727, 'lng': -6.126726429892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Fish Shack Sandycove',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3936,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105781730969918895094">stefan seibert</a>'],
#     'photo_reference': 'Aap_uEDUQyYJm0e1wWaoKtV2urGcyxiW83rTflgctuXUX_LB5V45dEquAmGYLVZzBi8OoPZLKzNhyLtDN2MzTywLboE16yqtGUcABV-vc6Y2wunOFjX518kjmD4o2oDClg0fo37n3E7ACLVdrHpWSR0aDKVUjGQ41740ohV5uuB-Fu25lYTP',
#     'width': 5248}],
#   'place_id': 'ChIJ2fsoXDoGZ0gRAi-0P4JFVks',
#   'plus_code': {'compound_code': '7VQF+MR Dublin, Ireland',
#    'global_code': '9C5M7VQF+MR'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJ2fsoXDoGZ0gRAi-0P4JFVks',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 776},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Unit 8 The Pavilion, Marine Rd, Dún Laoghaire, Dublin, A96 P272, Ireland',
#   'geometry': {'location': {'lat': 53.2939776, 'lng': -6.1333199},
#    'viewport': {'northeast': {'lat': 53.29554997989272,
#      'lng': -6.132164020107278},
#     'southwest': {'lat': 53.29285032010727, 'lng': -6.134863679892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Casper & Giumbini's",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2268,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111290023844083165928">simon sara</a>'],
#     'photo_reference': 'Aap_uEC_08ut5LzXKEJhO6vN2vBGCKCX9JqN_adpfjNJ7dDlUGr9g0eLXHE9EJsR1MXD76YuvFLRYQyEIsEu1lh4Kd9H9k6gKsGLtmFKh26HyxU1TClwQEtBA3zuTENuP-EWV4srN3oXkAYxiJYGkHfi8W0e_c2UAr4YVcg8D703Zk5AF1nc',
#     'width': 4032}],
#   'place_id': 'ChIJobaXivUHZ0gRKDfff7rq88I',
#   'plus_code': {'compound_code': '7VV8+HM Dublin, Ireland',
#    'global_code': '9C5M7VV8+HM'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJobaXivUHZ0gRKDfff7rq88I',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 406},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Stillorgan Rd, Stillorgan, Dublin, A94 V6K5, Ireland',
#   'geometry': {'location': {'lat': 53.2952012, 'lng': -6.2027266},
#    'viewport': {'northeast': {'lat': 53.29665752989273,
#      'lng': -6.201425420107276},
#     'southwest': {'lat': 53.29395787010728, 'lng': -6.20412507989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Purple Sage Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2048,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106633372496694306459">Purple Sage Restaurant</a>'],
#     'photo_reference': 'Aap_uEDxdS5o9A3gECZI4wXfqWCa8SRNFT1zJAd-DQpP1tH3n6Kd-l_yNWhNfGSH1SDGgmZTBbMPiCaXzFnKkkLCYAtE-KlCjNCyDMntinaaAESyfAG8upyi_vY1Wy-eO8VncUt3Xq0m-31zBGSiYioarGFYbzMS-xAqQBvYPi3qVkDj_PMB',
#     'width': 1638}],
#   'place_id': 'ChIJ0ctFIyAJZ0gRZMBxr9sPBoo',
#   'plus_code': {'compound_code': '7QWW+3W Dublin, Ireland',
#    'global_code': '9C5M7QWW+3W'},
#   'rating': 4.3,
#   'reference': 'ChIJ0ctFIyAJZ0gRZMBxr9sPBoo',
#   'types': ['restaurant',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 37},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '25 Main St, Clongriffin, Dublin 13, D13 T6W9, Ireland',
#   'geometry': {'location': {'lat': 53.4025025, 'lng': -6.153489899999999},
#    'viewport': {'northeast': {'lat': 53.40387357989271,
#      'lng': -6.152102820107277},
#     'southwest': {'lat': 53.40117392010727, 'lng': -6.154802479892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ravello Restaurant',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104068962840518304435">A Google User</a>'],
#     'photo_reference': 'Aap_uEBtdsJvGAXJwAj6ohYbaUXETyEqF3ngLARSsur7TiuoBqGAx3-OtBPqevve7tnkAcRUokVcXLUbWrl-LKW2N6A3YZRnMUI11pAwFfecekxxJJ_6OHC5aZM89VxV4XN_-r4apAHgfdDW700ejX8adWCkrEzoaS-osecpEM4SflEeAMw',
#     'width': 1280}],
#   'place_id': 'ChIJFdm4wpkEZ0gRbONqCj3im64',
#   'plus_code': {'compound_code': 'CR2W+XH Clongriffin, Dublin, Ireland',
#    'global_code': '9C5MCR2W+XH'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJFdm4wpkEZ0gRbONqCj3im64',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 263},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '27 Main St, Clongriffin, Dublin, D13 X8X9, Ireland',
#   'geometry': {'location': {'lat': 53.40248800000001,
#     'lng': -6.153384000000001},
#    'viewport': {'northeast': {'lat': 53.40388252989273,
#      'lng': -6.151999170107278},
#     'southwest': {'lat': 53.40118287010728, 'lng': -6.154698829892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Romayo's Diner Clongriffin",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113123883968485935055">Macaris Belmayne</a>'],
#     'photo_reference': 'Aap_uEDPq-Q_uCJRtm1l6fg3Kel0sdOgN-wklxhuP8tZ0i7w5NBQ3xS8fUgKwNgUYzgR2iaQcIKDBw806-NmzmbjgcHf6uu73cv9GAP0n1dcFBCU-0RGsXlTiN3AfbI4HPfz_CzGy9YnH3GxfJ6S7gzJENwv_tO36TkrYYGZbhXw7YaRHDdy',
#     'width': 1620}],
#   'place_id': 'ChIJ_cZQqU0FZ0gR4lpBXILm--w',
#   'plus_code': {'compound_code': 'CR2W+XJ Dublin, Ireland',
#    'global_code': '9C5MCR2W+XJ'},
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'ChIJ_cZQqU0FZ0gR4lpBXILm--w',
#   'types': ['restaurant',
#    'meal_delivery',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 305},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': "9 James's Terrace, Malahide, Co. Dublin, K36 KR66, Ireland",
#   'geometry': {'location': {'lat': 53.4516691, 'lng': -6.1517987},
#    'viewport': {'northeast': {'lat': 53.45301652989273,
#      'lng': -6.150375920107278},
#     'southwest': {'lat': 53.45031687010728, 'lng': -6.153075579892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Bon Appetit',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1440,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112534112357111096388">Raphael dos Santos</a>'],
#     'photo_reference': 'Aap_uEDxtc3qug008I1oaPqdfSI0yLK-DhO5eF_7c7oUaRsc52LiCskItCC7yh_lqRqHViimPi5MR4z4n9xcbvNclZ1-txuZETg1fH-NlCudK-6HdiJ_DhhMMi82bCHcvO31YyJkvqL9UgBw1fTIWpEDhVIbpasri9nbaqnrwpZVuKefnx8B',
#     'width': 2560}],
#   'place_id': 'ChIJk9rggWAaZ0gRoGhYMa7BLdY',
#   'plus_code': {'compound_code': 'FR2X+M7 Malahide, County Dublin, Ireland',
#    'global_code': '9C5MFR2X+M7'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJk9rggWAaZ0gRoGhYMa7BLdY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 765},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '63-65 Main St, Blackrock, Dublin, A94 X8P5, Ireland',
#   'geometry': {'location': {'lat': 53.3007326, 'lng': -6.175983899999999},
#    'viewport': {'northeast': {'lat': 53.30211292989272,
#      'lng': -6.174608520107278},
#     'southwest': {'lat': 53.29941327010727, 'lng': -6.177308179892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Coal',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1328,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109368445361986227628">Rage restaurant</a>'],
#     'photo_reference': 'Aap_uEByTjdheI9M3gHOoP1CRO8Y997M0tA_DtqCxlqjcMhwsEGCD0mAYU1V58rLk4gK6is0eP4s5wm-Vcmj01-31xr65gIcGrPRsuVIrazyNWAR5kQHcWmgfNW252-NOjz4lF8ANaiPV97a4aXn_0UGIddRtz_zqveoQvXY5s_mcZccfb1Y',
#     'width': 747}],
#   'place_id': 'ChIJMekUycAIZ0gRMlpNzQaeGmI',
#   'plus_code': {'compound_code': '8R2F+7J Dublin, Ireland',
#    'global_code': '9C5M8R2F+7J'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJMekUycAIZ0gRMlpNzQaeGmI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 346},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Monkstown Road Monkstown Rd, Monkstown, Co. Dublin, A94 E3F9, Ireland',
#   'geometry': {'location': {'lat': 53.29360759999999, 'lng': -6.1543736},
#    'viewport': {'northeast': {'lat': 53.29499397989271,
#      'lng': -6.153065470107278},
#     'southwest': {'lat': 53.29229432010727, 'lng': -6.155765129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Lobstar',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108092348602031381903">Lobstar</a>'],
#     'photo_reference': 'Aap_uEBfboSW9KvbOGWxmlZs_U72lsZwvzss42Dj49GC1fxgW3xjqaF8U9MX7qwVMrm-DLcW16iJ4aiqPR_bBL3Brg7Yl4htpBUc2pHWt_-EEqnSm8i7uruvL3udijRe3LIoOSjov2I8jaivERZTDoTohtMPA1HHyYJsjMpzGfP-0eTeyN-D',
#     'width': 960}],
#   'place_id': 'ChIJUUAQBpkIZ0gRfS45qTkAkmg',
#   'plus_code': {'compound_code': '7RVW+C6 Monkstown, County Dublin, Ireland',
#    'global_code': '9C5M7RVW+C6'},
#   'price_level': 3,
#   'rating': 4.8,
#   'reference': 'ChIJUUAQBpkIZ0gRfS45qTkAkmg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 350},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '23 Watermill Rd, Clontarf East, Raheny, Co. Dublin, D05 W322, Ireland',
#   'geometry': {'location': {'lat': 53.379216, 'lng': -6.176374},
#    'viewport': {'northeast': {'lat': 53.38047772989272,
#      'lng': -6.175070370107279},
#     'southwest': {'lat': 53.37777807010728, 'lng': -6.177770029892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Mulino Italian Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106846617075102039243">Chris McCauley</a>'],
#     'photo_reference': 'Aap_uEAlGihs5wEcK7ueJ2hUjIzfFkKJHnHyG7vX2O29Qs3ng99xeWsFCy5FXQWBcbXDHtCGmsrDLoBX5aOh2ilakCRD2rwXIaDiMRY2yAFzjsx5Pp9Y44bMZUOF4-3oM-qSxA6BKTA9KwIDnPBzFphp9CUMTi0mYXF9V8BV5iFBKIEJOVWU',
#     'width': 4032}],
#   'place_id': 'ChIJY8xSmo0PZ0gRAsc8n27woF4',
#   'plus_code': {'compound_code': '9RHF+MF Raheny, County Dublin, Ireland',
#    'global_code': '9C5M9RHF+MF'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJY8xSmo0PZ0gRAsc8n27woF4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 469},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '2 Ardcollum Ave, Beaumont, Dublin 5, D05 XW88, Ireland',
#   'geometry': {'location': {'lat': 53.3840498, 'lng': -6.2070025},
#    'viewport': {'northeast': {'lat': 53.38528062989272,
#      'lng': -6.205465120107278},
#     'southwest': {'lat': 53.38258097010727, 'lng': -6.208164779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Taza',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113508485472197013059">A Google User</a>'],
#     'photo_reference': 'Aap_uEDMPKb1Zb9qbc_2witU_VQlbQHB0KQ0CTNm5QNQUTw7EQe_1jYl7e8Q9R4WxeZf2FIRXtUd_BBmVjv5xdb4tegfOqBUubjPPT6qsNmAXTytXnu03E8xDKcDvfKwCzBs6mdFwGNMGz7Et2ICZ8V_ZxQ8PlpKF8ZyhOnETt2idZuVTrwR',
#     'width': 2268}],
#   'place_id': 'ChIJO7_RafUPZ0gRc0fqkU5sknY',
#   'plus_code': {'compound_code': '9QMV+J5 Dublin 5, Ireland',
#    'global_code': '9C5M9QMV+J5'},
#   'rating': 4.7,
#   'reference': 'ChIJO7_RafUPZ0gRc0fqkU5sknY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 598},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '193 Clontarf Rd, Clontarf East, Dublin 3, D03 E9P6, Ireland',
#   'geometry': {'location': {'lat': 53.3593695, 'lng': -6.1963405},
#    'viewport': {'northeast': {'lat': 53.36059857989272,
#      'lng': -6.195098970107279},
#     'southwest': {'lat': 53.35789892010727, 'lng': -6.197798629892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The Sandbar',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2336,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106918984607334611849">Patrick D</a>'],
#     'photo_reference': 'Aap_uECuKtOx0PiKcXLorebqC9uKCq8ewaSBpciany79RV5vQmr8UmOh0ekG2njYNyvkK30G0aDxAjHzBUgVoLdnk5qhhpTR57aclrLgdbrE3FcHnGQLyixkD2yMbgNtuC3HWi6yKWNwKanZ8VEHZPY3NJ31v9RrKEqBgYSt9VctwcsSsCnb',
#     'width': 4160}],
#   'place_id': 'ChIJC8yn2wkPZ0gRJACAnBaCE_c',
#   'plus_code': {'compound_code': '9R53+PF Dublin 3, Ireland',
#    'global_code': '9C5M9R53+PF'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJC8yn2wkPZ0gRJACAnBaCE_c',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 256},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '123a Clontarf Rd, Clontarf, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.3597231, 'lng': -6.2053062},
#    'viewport': {'northeast': {'lat': 53.36137617989272,
#      'lng': -6.203536350000001},
#     'southwest': {'lat': 53.35867652010727, 'lng': -6.20693695}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The Baths at Clontarf',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117825965832123940348">A Google User</a>'],
#     'photo_reference': 'Aap_uEDF12d6Y3bZxFhQuTeBzddEVfsVmAb5co6sbaqEydz7adrpKyNbaUrDi6TJSj1LjetHUfUWWIgwxnHHRO0ddWorq24xkUdxC2TmZHkjtu8HsvI-drHARSdFz1txeeDtgKLJt5BDYBWvDQZhwtTFLfIjm9pc_vXxPbkInuadMz9iCwz9',
#     'width': 4608}],
#   'place_id': 'ChIJbU2L0akPZ0gR5DBqQ0tvM_w',
#   'plus_code': {'compound_code': '9Q5V+VV Dublin, Ireland',
#    'global_code': '9C5M9Q5V+VV'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJbU2L0akPZ0gR5DBqQ0tvM_w',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1333},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Old St, Malahide, Co. Dublin, K36 A262, Ireland',
#   'geometry': {'location': {'lat': 53.45200089999999, 'lng': -6.1548704},
#    'viewport': {'northeast': {'lat': 53.45334962989271,
#      'lng': -6.153549470107277},
#     'southwest': {'lat': 53.45064997010727, 'lng': -6.156249129892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Old Street Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1637,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109340022433241917344">A Google User</a>'],
#     'photo_reference': 'Aap_uECnl6Vtp02OJ6VijVs7jHxPAaxSFqY1NqD3ml3Jq9Lp6LegyXO9-_U-fg6kpOLb4N7MvwyzS9e9Bmo_v0LVA6H3eg8pSbLJsiL2u_iA-oWxD9l_F8y0qCrDInRSAwW0w5pWeE7VDD0fXXrv3bTuI_gncXCG0nVcdbg_iSSscJwF1_x6',
#     'width': 2000}],
#   'place_id': 'ChIJ8bhY42AaZ0gRFuuhMHs2XAo',
#   'plus_code': {'compound_code': 'FR2W+R3 Malahide, County Dublin, Ireland',
#    'global_code': '9C5MFR2W+R3'},
#   'price_level': 3,
#   'rating': 4.5,
#   'reference': 'ChIJ8bhY42AaZ0gRFuuhMHs2XAo',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 403},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1 Moat Ln, Clontarf, Dublin 3, D03 N773, Ireland',
#   'geometry': {'location': {'lat': 53.359313, 'lng': -6.195875},
#    'viewport': {'northeast': {'lat': 53.36060332989272,
#      'lng': -6.194619470107277},
#     'southwest': {'lat': 53.35790367010727, 'lng': -6.197319129892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Picasso Restaurant Clontarf',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108572352251316003106">Picasso Restaurant Clontarf</a>'],
#     'photo_reference': 'Aap_uECMdy3EaVCb9ECNk7Sd56AzgTfvD4UgENlju3ElUsKpFuxHcVYKFzZMCNZcBHtb3HXIOLq52SZuX5NZ2V2pNfkUXPbFz7U4mgdFjvewqPdeeq4pJI67JMkLRlwI0eGYg39YIpgo3GPBoNH4NyGGe0FmiSuX06DTCx0ifxnB-tlsXocc',
#     'width': 2048}],
#   'place_id': 'ChIJI2vf3AkPZ0gR7xIWgpzwmrQ',
#   'plus_code': {'compound_code': '9R53+PJ Dublin 3, Ireland',
#    'global_code': '9C5M9R53+PJ'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJI2vf3AkPZ0gR7xIWgpzwmrQ',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 301},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': "opposite The Cedar Lounge, 59 St Assam's Park, Donaghmede, Dublin 5, D05 W8N1, Ireland",
#   'geometry': {'location': {'lat': 53.3812321, 'lng': -6.1655798},
#    'viewport': {'northeast': {'lat': 53.38260697989272,
#      'lng': -6.164030570107279},
#     'southwest': {'lat': 53.37990732010728, 'lng': -6.166730229892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Mc Hugh's Wine & Dine Restaurant, Raheny",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111842817927761686327">Barry McGovern</a>'],
#     'photo_reference': 'Aap_uEB83XSkEByY4taXZn4oO2WJgeD2FBTxwO2BfAdu5DJq_O_vExBSnBN2-z3adlkQKFHsbPRmz16RwbqqbcIqgpQHPKDdTNxZoQoQtTwYfW1XlTUrUnHpF8z81X2v30xnQYCMSVuyV4fvXFuTGLngqNCSjhVUwrPSNA4PCEioKOLp_-bU',
#     'width': 4032}],
#   'place_id': 'ChIJeUjsk4oPZ0gRwz8-jfHKY9E',
#   'plus_code': {'compound_code': '9RJM+FQ Dublin 5, Ireland',
#    'global_code': '9C5M9RJM+FQ'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJeUjsk4oPZ0gRwz8-jfHKY9E',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 424},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '5 Windsor Terrace, Dún Laoghaire, Dublin, A96 TW50, Ireland',
#   'geometry': {'location': {'lat': 53.2902475, 'lng': -6.1271814},
#    'viewport': {'northeast': {'lat': 53.29166382989272,
#      'lng': -6.125761020107277},
#     'southwest': {'lat': 53.28896417010728, 'lng': -6.128460679892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Toscana Italian Restaurant Dun Laoghaire Dublin',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 381,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107294134678643191101">Toscana Restaurant Dun Laoghaire</a>'],
#     'photo_reference': 'Aap_uECUovXYmvQ-QKGqhWksoDPUGsRVeokPe1rIFVwnzOs1lPotxFzDT-OSYtY2CjVOcF85Xd2MwIbQmXewe26oCTu6okYX6j2M06w4eYbLXo8YwM8XdedOZf77uiuPvZt9n63N7TbI7TuZX4vc-v3KyEFlf0idHbTeg3VwQKngd4y1zOQb',
#     'width': 533}],
#   'place_id': 'ChIJSU2jHTsGZ0gRmkkjutP70os',
#   'plus_code': {'compound_code': '7VRF+34 Dublin, Ireland',
#    'global_code': '9C5M7VRF+34'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJSU2jHTsGZ0gRmkkjutP70os',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 675},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '2B Vernon Ave, Clontarf East, Dublin, D03 R1W4, Ireland',
#   'geometry': {'location': {'lat': 53.3594883, 'lng': -6.1961419},
#    'viewport': {'northeast': {'lat': 53.36083297989272,
#      'lng': -6.194725620107278},
#     'southwest': {'lat': 53.35813332010727, 'lng': -6.197425279892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Hemmingways Restaurant Clontarf',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105053756299091610860">Brian Creedon</a>'],
#     'photo_reference': 'Aap_uEByxyLWz-gl6-A6wwwP2v1KDKsP3az1zEd_3azlQqPcLj1HxtkhVDnpx8vFtOXiMp-UU_q3you9yifRJRmJjAmSGpNPqiqS7FWt0lALW5tnFwVsiqlOEzrkbYcMKUm0UXX9SJo-3V8fGvwFJMZeECsR37JAlbhhxkhkZQcVbRy1j0w0',
#     'width': 1080}],
#   'place_id': 'ChIJNyYT3gkPZ0gRHBEQJnBaoC4',
#   'plus_code': {'compound_code': '9R53+QG Dublin, Ireland',
#    'global_code': '9C5M9R53+QG'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJNyYT3gkPZ0gRHBEQJnBaoC4',
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 200},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '318 Clontarf Rd, Clontarf, Dublin 3, D03 HD91, Ireland',
#   'geometry': {'location': {'lat': 53.36077969999999,
#     'lng': -6.182979800000001},
#    'viewport': {'northeast': {'lat': 53.36207422989272,
#      'lng': -6.181570870107278},
#     'southwest': {'lat': 53.35937457010728, 'lng': -6.184270529892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Kinara',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105348229603214120807">Arlene Castro Estrada</a>'],
#     'photo_reference': 'Aap_uECS1H41AnAtLJcp8oB5T7nxN3EiBmPq7PX0rTw_2CErm4AMcC-qFBVtgs6X6sQ3rvG-77jKsNftVUCrDSeTFlSMb0QsL0qXseveUjLSESCRpVhYgdUScL3Pd4PBrXUBmiqKKJtrHh-uAzp5st47MnN6Z1j2htIbKlmViKavc8YZz8PW',
#     'width': 4032}],
#   'place_id': 'ChIJj6d5Jp4PZ0gRs8T9Rw_Nyvc',
#   'plus_code': {'compound_code': '9R68+8Q Dublin 3, Ireland',
#    'global_code': '9C5M9R68+8Q'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJj6d5Jp4PZ0gRs8T9Rw_Nyvc',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 888},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Vernon Ave, Clontarf East, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.3599489, 'lng': -6.19577},
#    'viewport': {'northeast': {'lat': 53.36130347989272,
#      'lng': -6.194508220107278},
#     'southwest': {'lat': 53.35860382010728, 'lng': -6.197207879892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The Pigeon House Clontarf',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 673,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104782582753270716084">The Pigeon House</a>'],
#     'photo_reference': 'Aap_uECR2SIGhuyp6PlN6fj-9P6fpykaIhHFIDVYvl6EmBww4SHvuNYqp6N3F9q-0dPJEioTEao9IVyHx9ZYEWZtcJXidcf0X8MKtC89JizyKmAAadtM0mvH8cwSLaLuKIyo2dAdVC5Ee8pY3RjtLHOiqpMlabmKb7cLXuecEIr0d0CmEJX5',
#     'width': 999}],
#   'place_id': 'ChIJuf-7XqcPZ0gRhAUB75_DQKo',
#   'plus_code': {'compound_code': '9R53+XM Dublin, Ireland',
#    'global_code': '9C5M9R53+XM'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJuf-7XqcPZ0gRhAUB75_DQKo',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 870},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '19c, Main St, Malahide Rd, Kilmore, Dublin 5, D05 V180, Ireland',
#   'geometry': {'location': {'lat': 53.3887443, 'lng': -6.2009582},
#    'viewport': {'northeast': {'lat': 53.39008452989272,
#      'lng': -6.199531170107277},
#     'southwest': {'lat': 53.38738487010728, 'lng': -6.202230829892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Joe's Village Kitchen",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1836,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117405619661876664878">A Google User</a>'],
#     'photo_reference': 'Aap_uEAShusojWlXE2WYCJDO98ERr9HrKMpp3irHyU2Pfr4of7KKKVExRanVPYugsK3b7utj4FxM6nxrxhU8AnGrmb6fsh-ceF4S9Q1pl7AdzcWrNUG0r7TdUxOV-TYiERnpAATD8EAPC8jNs0dQzTKH03SgHzoTQc7_wgEPr-1nZEC7VK5k',
#     'width': 3264}],
#   'place_id': 'ChIJe3lmv7QPZ0gREZf8tni8GEM',
#   'plus_code': {'compound_code': '9QQX+FJ Dublin, Ireland',
#    'global_code': '9C5M9QQX+FJ'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'ChIJe3lmv7QPZ0gREZf8tni8GEM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 240},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '467 Strand Rd, Carrickhill, Portmarnock, Co. Dublin, D13 PA97, Ireland',
#   'geometry': {'location': {'lat': 53.4324774, 'lng': -6.1249856},
#    'viewport': {'northeast': {'lat': 53.43381147989273,
#      'lng': -6.123503720107278},
#     'southwest': {'lat': 53.43111182010728, 'lng': -6.126203379892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Lali's Restaurant Strand Road Portmarnock Co Dublin",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106822245349560555108">Anastasia Novikova</a>'],
#     'photo_reference': 'Aap_uEDLF4cluuDYsOvJ0WcueRbxM1z5aXRtC7xKoMqVoyQRDI_7KXHAxUW01lxynFkKvFGpu-KYazNpueyNueUUnIBp0j3GROom1RYDIFS803_yQkqaCkEeDCA8JtjONNTCkh1Huhvd3pbIVrouaIV2ZUzg-xlbNmpAIou76bhSmRsW54hs',
#     'width': 4160}],
#   'place_id': 'ChIJLQvDQeEaZ0gR5OoIOd7kKoY',
#   'plus_code': {'compound_code': 'CVJG+X2 Portmarnock, County Dublin, Ireland',
#    'global_code': '9C5MCVJG+X2'},
#   'rating': 4.3,
#   'reference': 'ChIJLQvDQeEaZ0gR5OoIOd7kKoY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 107},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': "9 George's Ave, Blackrock, Co. Dublin, A94 N563, Ireland",
#   'geometry': {'location': {'lat': 53.3015663, 'lng': -6.1789836},
#    'viewport': {'northeast': {'lat': 53.30288362989272,
#      'lng': -6.177579420107278},
#     'southwest': {'lat': 53.30018397010728, 'lng': -6.180279079892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Le Pastis',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 480,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118224866307492865484">Irma S</a>'],
#     'photo_reference': 'Aap_uEB5z54EyMTfPC73LX5gdncOyDeVfZDwPM8g6nBPyRoaP4CcYqzqOqOc2iKC6Z88bs46488UBX6bkTM9qPSBoEjJagclq78MKwSvbG-G6rqcTs-2LrjUUk1RtbTtZHYYXs5Mc8TeFgyAMHiFwK5eCJ6bBu0J8kSfEoe-eBGcGHGKkGuA',
#     'width': 640}],
#   'place_id': 'ChIJCV3PyMYIZ0gRtrwT6T8dpKQ',
#   'plus_code': {'compound_code': '8R2C+JC Blackrock, County Dublin, Ireland',
#    'global_code': '9C5M8R2C+JC'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJCV3PyMYIZ0gRtrwT6T8dpKQ',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 190},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '4 Main St, Howth, Dublin, D13 H2Y0, Ireland',
#   'geometry': {'location': {'lat': 53.38582299999999, 'lng': -6.0652531},
#    'viewport': {'northeast': {'lat': 53.38719367989272,
#      'lng': -6.063835670107279},
#     'southwest': {'lat': 53.38449402010727, 'lng': -6.066535329892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The House Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112912641495196534157">Chris Cross</a>'],
#     'photo_reference': 'Aap_uEB2DCOhgg7tZ0DDymU7Zj-958OXXtDUJclmrE9LK3ZHQef5kPoTiXCTVtAwcd5C1KYQqLpKjcbNF4if4Ek9cxd-mp67GGH35tYZl9zyIu7WQiteJ2HoMCBE8HnG2M_5k3qDD48m2G002rUsD6xpmGDqQvTrdco9mUFgAXquJ3nBts1l',
#     'width': 1920}],
#   'place_id': 'ChIJMx6oN5gEZ0gRa6x1K4B04sM',
#   'plus_code': {'compound_code': '9WPM+8V Dublin, Ireland',
#    'global_code': '9C5M9WPM+8V'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJMx6oN5gEZ0gRa6x1K4B04sM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 619},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Donaghmede SC Donaghmede Dublin 13, Ireland',
#   'geometry': {'location': {'lat': 53.3946962, 'lng': -6.1621977},
#    'viewport': {'northeast': {'lat': 53.39611902989272,
#      'lng': -6.160471670107277},
#     'southwest': {'lat': 53.39341937010728, 'lng': -6.163171329892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Kay's Kitchen",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107988364971146933301">eddie byrne</a>'],
#     'photo_reference': 'Aap_uEAjfXA0kb3WsdAGCor_OXwmr45gzUQRykO74s4T6UofQq1VFGGMlsi6n1iVsUU9f1jz_dfCSkpVKtLMcXHSbcVn-DNymBPktJ1lCQ61bmS-ZfRWffN1sDPaUuGWncU-LfoTAkWYEgHn1Den8i1DEKf-M40eYBTvQq9lwOnLXaZy2QaM',
#     'width': 2448}],
#   'place_id': 'ChIJz8z1W50OZ0gRZV5flCj8n0c',
#   'plus_code': {'compound_code': '9RVQ+V4 Dublin, Ireland',
#    'global_code': '9C5M9RVQ+V4'},
#   'rating': 3.9,
#   'reference': 'ChIJz8z1W50OZ0gRZV5flCj8n0c',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 133},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': "107 George's Street Lower, Dún Laoghaire, Dublin, A96 X771, Ireland",
#   'geometry': {'location': {'lat': 53.2938425, 'lng': -6.1394813},
#    'viewport': {'northeast': {'lat': 53.29515817989272,
#      'lng': -6.138165370107279},
#     'southwest': {'lat': 53.29245852010727, 'lng': -6.140865029892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The Sunshine Café & Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 6000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105070630386919225551">brian</a>'],
#     'photo_reference': 'Aap_uEDSaH7tpXDc0uL5dU5vNR-QZFPlrWTfDKeeqWj_GSpIJ9_CWyf-2pz26SODjILm8Il3r7ho4hB1k4firjsvS7pEyxyKdZe0bF9ctC4zWYaT36YTJXfSNri5QetCBue0WNqH6inJKZ-Jgs--JlYPSbOfr-ORILme3psywo8PlgjIGC-r',
#     'width': 4000}],
#   'place_id': 'ChIJkVERFCEGZ0gRapOiNnFf17c',
#   'plus_code': {'compound_code': '7VV6+G6 Dublin, Ireland',
#    'global_code': '9C5M7VV6+G6'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJkVERFCEGZ0gRapOiNnFf17c',
#   'types': ['restaurant',
#    'cafe',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 443},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '4a Monkstown Cres, Monkstown, Dublin, A94 VK30, Ireland',
#   'geometry': {'location': {'lat': 53.2939909, 'lng': -6.153327399999999},
#    'viewport': {'northeast': {'lat': 53.29528232989272,
#      'lng': -6.151978220107278},
#     'southwest': {'lat': 53.29258267010728, 'lng': -6.154677879892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Bresson - Fine Dining Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107834490306755650187">A Google User</a>'],
#     'photo_reference': 'Aap_uEDaaykhBTIRBYDBV59OlrhBiqKanDSmyYc_TJABNHdLnKsh23QjjEihgI5ebQjp0o3AuTI0zMGV5U0HhBwSVE2kqLB65P_Tp0jPuGVw0c5OZ0RUzgHXsdXCDz8K6aSsOEcnIdQJxDcwDe78IXU2LRqmDixJJmI4FH991o6GDBJiJtLC',
#     'width': 1920}],
#   'place_id': 'ChIJc2UbH5kIZ0gRQr-0_7a4sOY',
#   'plus_code': {'compound_code': '7RVW+HM Dublin, Ireland',
#    'global_code': '9C5M7RVW+HM'},
#   'price_level': 3,
#   'rating': 4.6,
#   'reference': 'ChIJc2UbH5kIZ0gRQr-0_7a4sOY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 331},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1 Grove Rd, Malahide, Co. Dublin, K36 NC44, Ireland',
#   'geometry': {'location': {'lat': 53.449986, 'lng': -6.1483865},
#    'viewport': {'northeast': {'lat': 53.45134587989272,
#      'lng': -6.147215820107277},
#     'southwest': {'lat': 53.44864622010728, 'lng': -6.149915479892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Coast Restaurant',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJ7QdLEl8aZ0gRbUXlBoO4H9c',
#   'plus_code': {'compound_code': 'CVX2+XM Malahide, County Dublin, Ireland',
#    'global_code': '9C5MCVX2+XM'},
#   'rating': 3.3,
#   'reference': 'ChIJ7QdLEl8aZ0gRbUXlBoO4H9c',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 3},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '2A Main St, Donaghmede, Dublin 5, D05 K3K6, Ireland',
#   'geometry': {'location': {'lat': 53.37993489999999, 'lng': -6.1748397},
#    'viewport': {'northeast': {'lat': 53.38128192989272,
#      'lng': -6.173579520107277},
#     'southwest': {'lat': 53.37858227010727, 'lng': -6.176279179892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The Mint Cottage',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2464,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101483141307285250695">Dublin Web Design</a>'],
#     'photo_reference': 'Aap_uED3wSK10LYt6LsFgKCb69g1yG81Wx3d-KhcOszmlpeD8Y488qbhR1NhK9wMmqdsareHbZv-1ZKiOGcPdpH7XEPQpbXCr7DjtVHDVs_Isps3LmrBfg0xQKnavHQG6kztoUpDtkkFmKa_q59Y7AOLySIa7JyOKrAc1k4lvNgYZ3UzTXBJ',
#     'width': 3696}],
#   'place_id': 'ChIJI8jmBo0PZ0gRheBlj20xRok',
#   'plus_code': {'compound_code': '9RHG+X3 Dublin 5, Ireland',
#    'global_code': '9C5M9RHG+X3'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJI8jmBo0PZ0gRheBlj20xRok',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 266},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Kingsford Cross, 2 Strand Rd, Burrow, Portmarnock, Co. Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.4226252, 'lng': -6.1351325},
#    'viewport': {'northeast': {'lat': 53.42393357989272,
#      'lng': -6.133714970107278},
#     'southwest': {'lat': 53.42123392010728, 'lng': -6.136414629892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "McHugh's Wine & Dine Restaurant, Portmarnock",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3840,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105119119603263111976">Eleanor Rafferty</a>'],
#     'photo_reference': 'Aap_uEBHAhSH-K04qT-vZfNr9SM7rwYpmPT6bh3Bx7nvDGMdirVP6pFv4liqlOKyLmUU6rOaqNtbt-jC2M8DAVlnuShcJZmYal9P6YR5nGPcn-Y4C0Dj-1W-VBek1If1uJ9YNzUJG2obzgiJb9Rf8V5vLvZUcX_J0khZ7wm2-ezbhpG4ivya',
#     'width': 2160}],
#   'place_id': 'ChIJq6rahsMaZ0gRQ94d0fP1-Yg',
#   'plus_code': {'compound_code': 'CVF7+3W Portmarnock, County Dublin, Ireland',
#    'global_code': '9C5MCVF7+3W'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJq6rahsMaZ0gRQ94d0fP1-Yg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 259},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '4 Lower Kilmacud Rd, Stillorgan, Co. Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.2885251, 'lng': -6.1988981},
#    'viewport': {'northeast': {'lat': 53.28986727989273,
#      'lng': -6.197570420107279},
#     'southwest': {'lat': 53.28716762010728, 'lng': -6.200270079892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Riba Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 415,
# ...
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Hakka Choi Restaurant',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110452641555761570573">RANJITH B K</a>'],
#     'photo_reference': 'Aap_uEBE3x35Z1-ztrVQ-eZY-GobdEL-UrPqASoWMeLpUsP2jsmT-pKOxwkLpn6RNn-OBddLG21nOJQV_nkYPzEl7PDwkiEzQ4Z2aLLW-Ng2KIE6gYTeT7Go_RGXgXLZeD_v_yD8jjEgJ4Cxl-0M2aCtsa3PjxTvnA9pIOjvB2vbWY3QXksC',
#     'width': 4032}],
#   'place_id': 'ChIJN9KdbTQJZ0gRS8iPUBMPVQk',
#   'plus_code': {'compound_code': '7RVW+JP Monkstown, County Dublin, Ireland',
#    'global_code': '9C5M7RVW+JP'},
#   'rating': 4.4,
#   'reference': 'ChIJN9KdbTQJZ0gRS8iPUBMPVQk',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 44},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1 The Diamond, New St, Malahide, Co. Dublin, K36 V273, Ireland',
#   'geometry': {'location': {'lat': 53.45116290000001,
#     'lng': -6.153845599999999},
#    'viewport': {'northeast': {'lat': 53.45230447989272,
#      'lng': -6.152399520107278},
#     'southwest': {'lat': 53.44960482010728, 'lng': -6.155099179892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'FishShackCafé Malahide',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101494199755806406356">Martin King</a>'],
#     'photo_reference': 'Aap_uEDLRMVrhUJCu5lguhHrsWhOsNFMKZ-su69cdmj1ucMVvtUHwHdnk34NBHT2VaHWV372GiCKDDfpZ_clp-_i0t-gudRavh2PKY5xwd4zoChXZKuX9o63pcvmjYZ1BuobFFkU8Z9F0ppTXeYWA5pDYVjbIRHcBpnHjGn398eNDMeTtL1M',
#     'width': 5312}],
#   'place_id': 'ChIJP2KHWWAaZ0gRD9nMXXpvHQ0',
#   'plus_code': {'compound_code': 'FR2W+FF Malahide, County Dublin, Ireland',
#    'global_code': '9C5MFR2W+FF'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJP2KHWWAaZ0gRD9nMXXpvHQ0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 843},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Harbour House, Harbour Rd, Howth, Dublin, D13 E9H9, Ireland',
#   'geometry': {'location': {'lat': 53.3877377, 'lng': -6.068448699999999},
#    'viewport': {'northeast': {'lat': 53.38913152989273,
#      'lng': -6.067091320107278},
#     'southwest': {'lat': 53.38643187010729, 'lng': -6.069790979892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Mamó Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114551094811849682402">A Google User</a>'],
#     'photo_reference': 'Aap_uEDbLmzkvT0jgx-zpuMG5mVYYe08XqUEmGUb8ZKUUCi5yGZvscU0YBGWhYcxiCoym5mbwOIdZ-5Ov_X2JxL0fkHJxSpNGm8dw0rf9swRuZsUZFHjYEzkdbtUuhnC6t8tF3QM1I0N0GmuB4u9qvTKEasNkTEH1pcagQafKi54pZImnSdn',
#     'width': 2048}],
#   'place_id': 'ChIJoywvTpgFZ0gRxX8VJ8bhrCw',
#   'plus_code': {'compound_code': '9WQJ+3J Howth, Dublin, Ireland',
#    'global_code': '9C5M9WQJ+3J'},
#   'rating': 4.9,
#   'reference': 'ChIJoywvTpgFZ0gRxX8VJ8bhrCw',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 104},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'The Diamond, Main Street, Malahide, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.4506846, 'lng': -6.1533513},
#    'viewport': {'northeast': {'lat': 53.45205852989272,
#      'lng': -6.152063820107278},
#     'southwest': {'lat': 53.44935887010728, 'lng': -6.154763479892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'McGoverns Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4193,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107491397239366234607">Chris Castro</a>'],
#     'photo_reference': 'Aap_uEDKzruix2umTuqDePLiDJLCmNllA904HTjSD5_ATwZFbNsekSdfn6w5HI07Uz6K4MLLmKbus3lK64fCfUAP9Sar8IvgK8EiXpd0stzCv8DgLqSyaRY27HVXZ8y-cskuEDAuh5qwU8YMhtsN1RaJI78JaNhEJay_lLNr0MIIxcsBbg0',
#     'width': 3145}],
#   'place_id': 'ChIJ46Z8XGAaZ0gRZ01BErPmgcM',
#   'plus_code': {'compound_code': 'FR2W+7J Malahide, County Dublin, Ireland',
#    'global_code': '9C5MFR2W+7J'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJ46Z8XGAaZ0gRZ01BErPmgcM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 708},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Marine Hotel, Sutton Cross, Sutton, Dublin 13, D13 P3Y8, Ireland',
#   'geometry': {'location': {'lat': 53.3887948, 'lng': -6.110615},
#    'viewport': {'northeast': {'lat': 53.39019047989272,
#      'lng': -6.109120770107277},
#     'southwest': {'lat': 53.38749082010727, 'lng': -6.111820429892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Cucinos Italian Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112695120140681178296">Diana Thurmann</a>'],
#     'photo_reference': 'Aap_uEAiM2VCi40c-hyY3tLeG4NxGR5SsDByLusE7oCysF1sALUYYyQDU91hycoZFRUWAn7sZ_jxdISjIxG-ulpJ5ah0Ostgez4zlGUL8UmGMMNeT0z5fJWYhooBN11xtXINqCMRby25ehOZ4dPAeiJ83K30SHZNQHwiKigt2FSi5gUNTvcY',
#     'width': 4032}],
#   'place_id': 'ChIJt17EniAFZ0gR2IerZvzF6sI',
#   'plus_code': {'compound_code': '9VQQ+GQ Dublin 13, Ireland',
#    'global_code': '9C5M9VQQ+GQ'},
#   'rating': 3.9,
#   'reference': 'ChIJt17EniAFZ0gR2IerZvzF6sI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 61},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '10 Lower Kilmacud Rd, Stillorgan, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.288469, 'lng': -6.199466699999999},
#    'viewport': {'northeast': {'lat': 53.28988727989272,
#      'lng': -6.198157920107278},
#     'southwest': {'lat': 53.28718762010728, 'lng': -6.200857579892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Aprile Italian Seafood Restaurant 01 2100016',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 750,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100767832136684209143">A Google User</a>'],
#     'photo_reference': 'Aap_uEAs-G5LyqyL8GsSSiMdN0pIK0JbisxiouYEKZ-MWPiOftC8d6EnL-g5uoJrD23z57Ou4TNYxYiRB1uS3d2f9SwHFWqwffiLQgDBK1zl5R0ImmBTHmM4wrOfe56KS3d5X07Fv7yEH1TQE9G3Y-C9_iotgpIMGJqRC8iWANkrWQXK5g5K',
#     'width': 1334}],
#   'place_id': 'ChIJExz17RkJZ0gRQb3-7p8_ohk',
#   'plus_code': {'compound_code': '7RQ2+96 Dublin, Ireland',
#    'global_code': '9C5M7RQ2+96'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJExz17RkJZ0gRQb3-7p8_ohk',
#   'types': ['restaurant',
#    'meal_delivery',
#    'meal_takeaway',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 202},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '15 Patrick St, Dún Laoghaire, Dublin, A96 XT98, Ireland',
#   'geometry': {'location': {'lat': 53.2916527, 'lng': -6.1371984},
#    'viewport': {'northeast': {'lat': 53.29299372989272,
#      'lng': -6.135829870107278},
#     'southwest': {'lat': 53.29029407010728, 'lng': -6.138529529892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Bits & Pizzas Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3072,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106774622305935388974">Bits &amp; Pizzas Restaurant</a>'],
#     'photo_reference': 'Aap_uEAnYRbZV6ycgjW7uWo2lhzUElG08QzqoMmhDVblExJmRs3h8D1mdiSE0g_HoMk1kmCF9z6d2wMI6oHOgfzo_N4MN3ly04UDPOjVhuFEcDtE_syxTj3CWFGkoXWXeqfo6T2hq_wbzqQgZSTFDkC51EyyH4OYhgbQQ_ArxgFFP1PzgWwk',
#     'width': 4761}],
#   'place_id': 'ChIJQSj5pSYGZ0gRtOKuD-bRFH4',
#   'plus_code': {'compound_code': '7VR7+M4 Dublin, Ireland',
#    'global_code': '9C5M7VR7+M4'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJQSj5pSYGZ0gRtOKuD-bRFH4',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 478},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '12a New St, Malahide, Co. Dublin, K36 TW30, Ireland',
#   'geometry': {'location': {'lat': 53.4513257, 'lng': -6.1539002},
#    'viewport': {'northeast': {'lat': 53.45289037989272,
#      'lng': -6.152477720107278},
#     'southwest': {'lat': 53.45019072010728, 'lng': -6.155177379892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Al Fresco',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2592,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117318886560859347225">Paolo R</a>'],
#     'photo_reference': 'Aap_uEB1rxUzsfL4TV0uyMHxjgtLr9nK3Gf6-N6Oaz11C5t_gJuyU8C5dyZ7u2KB1joil1bhjyXBoT9Q4SRUNsraGLbW6VAgtQha4Dnsvv8memPPuvxkZPC-6enphl2w3-Kc6rB9DB_WlIsy9ToBBHXUkLbWzpmGTXnE1tLo8_RBTktPXH68',
#     'width': 4608}],
#   'place_id': 'ChIJH-UYX2AaZ0gRMbuHT2-XOv8',
#   'plus_code': {'compound_code': 'FR2W+GC Malahide, County Dublin, Ireland',
#    'global_code': '9C5MFR2W+GC'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJH-UYX2AaZ0gRMbuHT2-XOv8',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 441},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Harbour Square, Crofton Rd, Dún Laoghaire, Dun Laoghaire, Co. Dublin, A96 XV65, Ireland',
#   'geometry': {'location': {'lat': 53.29494039999999, 'lng': -6.1354659},
#    'viewport': {'northeast': {'lat': 53.29633947989272,
#      'lng': -6.134169120107278},
#     'southwest': {'lat': 53.29363982010727, 'lng': -6.136868779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Bistro Le Monde',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3662,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116618181801887621940">Travel Cafe &amp; Restaurant</a>'],
#     'photo_reference': 'Aap_uECPuQvE1yfackJOiu3nU-vm8woScUqkPJQ9Ftu0bYcaMnvzgFjtc7Kpzw7W5C2RTyXK4ytLRf7v0TdtmYy29RBZ1qB7jTP17ECinqoDwV7DXYoA_afUM_sgzTTAOKkMoGWK51BLMdm9TrJcAGweH2PvbD_Svu9ruCNvW2h2CbCoRwT7',
#     'width': 5493}],
#   'place_id': 'ChIJZd7isyMGZ0gRbrjQlDpLjIo',
#   'plus_code': {'compound_code': '7VV7+XR Dublin, Ireland',
#    'global_code': '9C5M7VV7+XR'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJZd7isyMGZ0gRbrjQlDpLjIo',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 157},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Howth, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.3886158, 'lng': -6.0725259},
#    'viewport': {'northeast': {'lat': 53.39001057989272,
#      'lng': -6.071161170107277},
#     'southwest': {'lat': 53.38731092010728, 'lng': -6.073860829892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Wrights Seafood & Steaks Bar & Restaurant',
#   'photos': [{'height': 3467,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101371816651237143855">Elias Wagner</a>'],
#     'photo_reference': 'Aap_uEBgxJQ4IxKsb9Rn1bkZDWITCBHBG8CfDMB5zBliypFv1ie3w3L2j48WQexWajAjEaCMc8M_DG3VGzLtijO2XmemB1o2FFrpNyFEvtowp5m8uZ6IqInYz9C4rjCENtp6Fs1LR59dcZv8yaQ-_MKwaTTzId5VUmDTLWEME6w81oqENc4',
#     'width': 4334}],
#   'place_id': 'ChIJl8Zsk70EZ0gR8-InG-nfFRA',
#   'plus_code': {'compound_code': '9WQG+CX Dublin, Ireland',
#    'global_code': '9C5M9WQG+CX'},
#   'rating': 5,
#   'reference': 'ChIJl8Zsk70EZ0gR8-InG-nfFRA',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '7 Rock Hill, Blackrock, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.3021298, 'lng': -6.178471999999999},
#    'viewport': {'northeast': {'lat': 53.30342982989272,
#      'lng': -6.177165720107278},
#     'southwest': {'lat': 53.30073017010728, 'lng': -6.179865379892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Old Post Office',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4640,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106977878551038687960">matea grganić</a>'],
#     'photo_reference': 'Aap_uED_K-eVvqKtn5oIhbMkbu5k_2tZMWKgVSKmG1crQV1JjHfrAbolIcsViySVBBAk9VSJ_q1UAIVgWDxetVeB2G4hy8hMO6NNcVZ6QiMofn_Csm6tyiuhjT-zNPvW7xYwoE8KVLxTF3_OchEWKviefX7pgz9QpIilTLQsMLIdyqY8Qr-h',
#     'width': 3488}],
#   'place_id': 'ChIJK1Bnn60JZ0gRvGE3irXRcrc',
#   'plus_code': {'compound_code': '8R2C+VJ Dublin, Ireland',
#    'global_code': '9C5M8R2C+VJ'},
#   'rating': 4.8,
#   'reference': 'ChIJK1Bnn60JZ0gRvGE3irXRcrc',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 54},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Unit 3, Harbour Square, Crofton Rd, Dún Laoghaire, Dublin, Ireland',
#   'geometry': {'location': {'lat': 53.29499999999999, 'lng': -6.1358333},
#    'viewport': {'northeast': {'lat': 53.29641252989271,
#      'lng': -6.134416620107278},
#     'southwest': {'lat': 53.29371287010727, 'lng': -6.137116279892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Gourmet Food Parlour Dun Laoghaire',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112251336272358592070">Thiago Azevedo</a>'],
#     'photo_reference': 'Aap_uEAixCIqCB3ne93bqekXb-pTNsN7KkiECZM51pdrY1O16xrTaK8ZLa31qZh31LCEDByADOEwuoNCNZD4GXlUg1gQVOtAuUVKvGjOQZyNCW5sQJO2o-6iDBqUWTrb63_rOyGWc9VS-Xd7X2xtlyYq959U9AWlRKX0-if8BBP_YWbrmOkh',
#     'width': 4048}],
#   'place_id': 'ChIJOS7kYyAGZ0gRBTWb2iIxofg',
#   'plus_code': {'compound_code': '7VV7+XM Dublin, Ireland',
#    'global_code': '9C5M7VV7+XM'},
#   'rating': 4.3,
#   'reference': 'ChIJOS7kYyAGZ0gRBTWb2iIxofg',
#   'types': ['restaurant',
#    'cafe',
#    'bar',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1010}]

# %%
df_dict = {'poi_name':poi_name, 'poi_address': poi_address, 'poi_lat': poi_lat, 'poi_lon' : poi_lon, 'poi_type': poi_type}

resturant_poi_df = pd.DataFrame(df_dict)

# %%
resturant_poi_df.head()
# Out:
#                              poi_name  \
# 0                      Bay Restaurant
# 1  Bianconi's Ristorante and Pizzeria
# 2                        8a Brasserie
# 3                          La Gustosa
# 4                     Suas Restaurant
#
#                                          poi_address    poi_lat   poi_lon  \
# 0       369 Clontarf Rd, Clontarf, Dublin 3, Ireland  53.363070 -6.178590
# 1        232 Merrion Rd, Dublin 4, D04 RH61, Ireland  53.317495 -6.208155
# 2  8A Monkstown Cres, Monkstown, Co. Dublin, A94 ...  53.293983 -6.152665
# 3  12a Dublin Rd, Bayside, Dublin 13, D13 RW26, I...  53.385571 -6.140592
# 4  411 Howth Rd, Clontarf East, Dublin 5, D05 Y1E...  53.379835 -6.177206
#
#                                             poi_type
# 0  [restaurant, food, point_of_interest, establis...
# 1  [restaurant, food, point_of_interest, establis...
# 2  [restaurant, food, point_of_interest, establis...
# 3  [meal_takeaway, restaurant, food, point_of_int...
# 4  [restaurant, bar, food, point_of_interest, est...

# %%
for lat, long, label in zip(resturant_poi_df.poi_lat, resturant_poi_df.poi_lon, resturant_poi_df.poi_name):
    folium.CircleMarker([lat, long], radius=10, popup=label, color='yellow', fill=True, fill_opacity=0.2).add_to(DublinEVMap)

DublinEVMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_d2c028b10b4fde4be632459fa3941aff {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_d2c028b10b4fde4be632459fa3941aff&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_d2c028b10b4fde4be632459fa3941aff = L.map(
#         &#x27;map_d2c028b10b4fde4be632459fa3941aff&#x27;, {
#         center: [53.347598, -6.259343],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_f76cb30f07a4c664ca464576bb8fdf93 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#             var circle_marker_8b0228e227caf0d57ef5bd37011f52f8 = L.circleMarker(
#                 [53.36693, -6.39284],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#
#             var popup_0a77fd1a2e99ef7c8eb94a6cf483878f = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_205fe05c73d7f7476fb71cc2835c5b2f = $(`&lt;div id=&quot;html_205fe05c73d7f7476fb71cc2835c5b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castleknock Hotel and Country Club, Porterstown Road, Castleknock, Dublin 15, County Dublin&lt;/div&gt;`)[0];
#                 popup_0a77fd1a2e99ef7c8eb94a6cf483878f.setContent(html_205fe05c73d7f7476fb71cc2835c5b2f);
#
#
#             circle_marker_8b0228e227caf0d57ef5bd37011f52f8.bindPopup(popup_0a77fd1a2e99ef7c8eb94a6cf483878f)
#             ;
#
#
#
#
#             var circle_marker_1f51a1a8d81198eb10e2a57d2eea17fc = L.circleMarker(
#                 [53.271314, -6.206086],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#
#             var popup_a60527579ebea0903b294de2524dbc79 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_e427a8b4e577be490292a117cb97f4e9 = $(`&lt;div id=&quot;html_e427a8b4e577be490292a117cb97f4e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bewleys Hotel Leopardstown, Central Park, Leopardstown, Dublin 18, County Dublin&lt;/div&gt;`)[0];
#                 popup_a60527579ebea0903b294de2524dbc79.setContent(html_e427a8b4e577be490292a117cb97f4e9);
#
#
#             circle_marker_1f51a1a8d81198eb10e2a57d2eea17fc.bindPopup(popup_a60527579ebea0903b294de2524dbc79)
#             ;
#
#
#
#
#             var circle_marker_14de1544531666bd2acc7ba31399ddf3 = L.circleMarker(
#                 [53.341351, -6.261259],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d2c028b10b4fde4be632459fa3941aff);
#
#
#             var popup_e8b8ae8a1187334afa9d1f9eb5e0cfc3 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_801b95b550b476491cb9b98b884eb96e = $(`&lt;div id=&quot;html_801b95b550b476491cb9b98b884eb96e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Westbury Hotel, Grafton Street, Dublin 2, County Dublin&lt;/div&gt;`)[0];
#                 popup_e8b8ae8a1187334afa9d1f9eb5e0cfc3.setContent(html_801b95b550b476491cb9b98b884eb96e);
#
#
#             circle_marker_14de1544531666bd2acc7ba31399ddf3.bindPopup(popup_e8b8ae8a1187334afa9d1f9eb5e0cfc3)
#             ;
#
#
#
#
#             var circle_marker_7558af9c6728889cc63d48d2152459df = L.circleMarker(
#                 [53.3385, -6.2529],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot
